# %%
import datetime
import json
from bs4 import BeautifulSoup
import requests
from dataclasses import dataclass


# -------------------------------------------
# Modify the holiday class to 
# 1. Only accept Datetime objects for date.
# 2. You may need to add additional functions
# 3. You may drop the init if you are using @dataclasses
# --------------------------------------------
class Holiday:
      
    def __init__(self,name, date): 
        self.name = name
        self.date = date    
    
    def __str__ (self):
        return (f'The holiday {self.name} is on {self.date}')

# %%
def getHTML(url):
    response = requests.get(url)
    return response.text

datehtml = getHTML('https://www.timeanddate.com/holidays/us/')

datesoup = BeautifulSoup(datehtml, 'html.parser')

holi_table = datesoup.find('section', attrs = {'class':'table-data__table'})
holi_body = holi_table.find('tbody')

holidays = []
    
for row in holi_body.find_all('tr'):
    cells = row.find_all('td')
    if len(cells) > 0:
        holiday = {}
        holiday['name'] = cells[1].string
        holiday['type'] = cells[2].string
        holidays.append(holiday)
        
holidaydates = []

for row in holi_body.find_all('tr'):
    cells = row.find_all('th')
    if len(cells) > 0:
        holidaydates.append(cells[0].string)
        
for i in range (len(holidays)):
    holidays[i]['date'] = holidaydates[i]

holidays
# Out:
# [{'name': "New Year's Day", 'type': 'Federal Holiday', 'date': 'Jan 1'},
#  {'name': "New Year's Day", 'type': 'State Holiday', 'date': 'Jan 1'},
#  {'name': "New Year's Day", 'type': 'State Holiday', 'date': 'Jan 1'},
#  {'name': "New Year's Day (substitute)",
#   'type': 'State Holiday',
#   'date': 'Jan 3'},
#  {'name': 'World Braille Day',
#   'type': 'United Nations observance',
#   'date': 'Jan 4'},
#  {'name': 'Epiphany', 'type': 'Christian', 'date': 'Jan 6'},
#  {'name': 'Orthodox Christmas Day', 'type': 'Orthodox', 'date': 'Jan 7'},
#  {'name': "International Programmers' Day",
#   'type': 'Worldwide observance',
#   'date': 'Jan 7'},
#  {'name': 'Estelle Reel Day', 'type': 'State Observance', 'date': 'Jan 7'},
#  {'name': 'Battle of New Orleans',
#   'type': 'State Legal Holiday',
#   'date': 'Jan 8'},
#  {'name': 'Stephen Foster Memorial Day',
#   'type': 'Observance',
#   'date': 'Jan 13'},
#  {'name': 'Orthodox New Year', 'type': 'Orthodox', 'date': 'Jan 14'},
#  {'name': 'World Religion Day',
#   'type': 'Worldwide observance',
#   'date': 'Jan 16'},
#  {'name': "Tu Bishvat/Tu B'Shevat",
#   'type': 'Jewish holiday',
#   'date': 'Jan 17'},
#  {'name': 'Martin Luther King Jr. Day',
#   'type': 'Federal Holiday',
#   'date': 'Jan 17'},
#  {'name': 'Martin Luther King Jr. Day',
#   'type': 'State Holiday',
#   'date': 'Jan 17'},
#  {'name': "Robert E. Lee's Birthday",
#   'type': 'State Holiday',
#   'date': 'Jan 17'},
#  {'name': 'Idaho Human Rights Day', 'type': 'State Holiday', 'date': 'Jan 17'},
#  {'name': 'Civil Rights Day', 'type': 'State Holiday', 'date': 'Jan 17'},
#  {'name': "Robert E. Lee's Birthday",
#   'type': 'State Legal Holiday',
#   'date': 'Jan 19'},
#  {'name': 'State Holiday', 'type': 'State Observance', 'date': 'Jan 19'},
#  {'name': "Confederate Heroes' Day",
#   'type': 'State Holiday',
#   'date': 'Jan 19'},
#  {'name': 'International Day of Education',
#   'type': 'United Nations observance',
#   'date': 'Jan 24'},
#  {'name': 'International Customs Day',
#   'type': 'Worldwide observance',
#   'date': 'Jan 26'},
#  {'name': 'International Day of Commemoration in Memory of the Victims of the Holocaust',
#   'type': 'United Nations observance',
#   'date': 'Jan 27'},
#  {'name': 'Kansas Day', 'type': 'State Observance', 'date': 'Jan 29'},
#  {'name': 'World Leprosy Day',
#   'type': 'Worldwide observance',
#   'date': 'Jan 30'},
#  {'name': 'National Freedom Day', 'type': 'Observance', 'date': 'Feb 1'},
#  {'name': 'Lunar New Year', 'type': 'Observance', 'date': 'Feb 1'},
#  {'name': 'First Day of Black History Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'Feb 1'},
#  {'name': 'World Wetlands Day',
#   'type': 'Worldwide observance',
#   'date': 'Feb 2'},
#  {'name': 'Groundhog Day', 'type': 'Observance', 'date': 'Feb 2'},
#  {'name': 'National Girls and Women in Sports Day',
#   'type': 'Observance',
#   'date': 'Feb 2'},
#  {'name': 'International Day of Human Fraternity',
#   'type': 'United Nations observance',
#   'date': 'Feb 4'},
#  {'name': 'World Cancer Day', 'type': 'Worldwide observance', 'date': 'Feb 4'},
#  {'name': 'Rosa Parks Day', 'type': 'Local observance', 'date': 'Feb 4'},
#  {'name': 'Rosa Parks Day', 'type': 'State Observance', 'date': 'Feb 4'},
#  {'name': 'National Wear Red Day', 'type': 'Observance', 'date': 'Feb 4'},
#  {'name': 'International Day of Zero Tolerance for Female Genital Mutilation',
#   'type': 'United Nations observance',
#   'date': 'Feb 6'},
#  {'name': 'Ronald Reagan Day', 'type': 'State Observance', 'date': 'Feb 6'},
#  {'name': 'World Pulses Day',
#   'type': 'United Nations observance',
#   'date': 'Feb 10'},
#  {'name': 'International Day of Women and Girls in Science',
#   'type': 'United Nations observance',
#   'date': 'Feb 11'},
#  {'name': 'World Day of the Sick',
#   'type': 'Worldwide observance',
#   'date': 'Feb 11'},
#  {'name': "Lincoln's Birthday observed",
#   'type': 'State Holiday',
#   'date': 'Feb 11'},
#  {'name': "Lincoln's Birthday", 'type': 'State Holiday', 'date': 'Feb 12'},
#  {'name': "Lincoln's Birthday",
#   'type': 'State Legal Holiday',
#   'date': 'Feb 12'},
#  {'name': 'Georgia Day', 'type': 'State Observance', 'date': 'Feb 12'},
#  {'name': 'World Radio Day',
#   'type': 'United Nations observance',
#   'date': 'Feb 13'},
#  {'name': 'Super Bowl', 'type': 'Sporting event', 'date': 'Feb 13'},
#  {'name': "Valentine's Day", 'type': 'Observance', 'date': 'Feb 14'},
#  {'name': 'Statehood Day', 'type': 'Local observance', 'date': 'Feb 14'},
#  {'name': "Susan B. Anthony's Birthday",
#   'type': 'State Observance',
#   'date': 'Feb 15'},
#  {'name': 'Elizabeth Peratrovich Day',
#   'type': 'State Observance',
#   'date': 'Feb 16'},
#  {'name': 'World Day of Social Justice',
#   'type': 'United Nations observance',
#   'date': 'Feb 20'},
#  {'name': 'International Mother Language Day',
#   'type': 'United Nations observance',
#   'date': 'Feb 21'},
#  {'name': "Presidents' Day", 'type': 'Federal Holiday', 'date': 'Feb 21'},
#  {'name': "Presidents' Day", 'type': 'State Holiday', 'date': 'Feb 21'},
#  {'name': "Presidents' Day", 'type': 'State Legal Holiday', 'date': 'Feb 21'},
#  {'name': 'Daisy Gatson Bates Day', 'type': 'State Holiday', 'date': 'Feb 21'},
#  {'name': 'African-American Scientist and Inventor Day',
#   'type': 'State Observance',
#   'date': 'Feb 25'},
#  {'name': 'George Rogers Clark Day',
#   'type': 'State Observance',
#   'date': 'Feb 25'},
#  {'name': 'Maha Shivaratri', 'type': 'Hindu Holiday', 'date': 'Feb 28'},
#  {'name': 'Linus Pauling Day', 'type': 'Local observance', 'date': 'Feb 28'},
#  {'name': "Isra and Mi'raj", 'type': 'Muslim', 'date': 'Mar 1'},
#  {'name': 'Zero Discrimination Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 1'},
#  {'name': 'Self-Injury Awareness Day',
#   'type': 'Worldwide observance',
#   'date': 'Mar 1'},
#  {'name': 'Shrove Tuesday/Mardi Gras',
#   'type': 'State Holiday',
#   'date': 'Mar 1'},
#  {'name': 'Shrove Tuesday/Mardi Gras',
#   'type': 'Observance, Christian',
#   'date': 'Mar 1'},
#  {'name': "St. David's Day", 'type': 'Observance, Christian', 'date': 'Mar 1'},
#  {'name': 'Town Meeting Day', 'type': 'State Holiday', 'date': 'Mar 1'},
#  {'name': "First Day of Women's History Month",
#   'type': 'Annual Monthly Observance',
#   'date': 'Mar 1'},
#  {'name': 'First Day of Irish American Heritage Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'Mar 1'},
#  {'name': 'Ash Wednesday', 'type': 'Christian', 'date': 'Mar 2'},
#  {'name': 'Texas Independence Day', 'type': 'State Holiday', 'date': 'Mar 2'},
#  {'name': 'Read Across America Day', 'type': 'Observance', 'date': 'Mar 2'},
#  {'name': 'World Wildlife Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 3'},
#  {'name': 'Casimir Pulaski Day', 'type': 'State Observance', 'date': 'Mar 4'},
#  {'name': 'Employee Appreciation Day', 'type': 'Observance', 'date': 'Mar 4'},
#  {'name': 'Casimir Pulaski Day', 'type': 'State Observance', 'date': 'Mar 7'},
#  {'name': "International Women's Day",
#   'type': 'United Nations observance',
#   'date': 'Mar 8'},
#  {'name': 'International Day of Women Judges',
#   'type': 'United Nations observance',
#   'date': 'Mar 10'},
#  {'name': 'World Kidney Day',
#   'type': 'Worldwide observance',
#   'date': 'Mar 10'},
#  {'name': 'Daylight Saving Time starts',
#   'type': 'Clock change/Daylight Saving Time',
#   'date': 'Mar 13'},
#  {'name': 'Purim', 'type': 'Jewish holiday', 'date': 'Mar 17'},
#  {'name': "St. Patrick's Day",
#   'type': 'Observance, Christian',
#   'date': 'Mar 17'},
#  {'name': 'Evacuation Day', 'type': 'State Holiday', 'date': 'Mar 17'},
#  {'name': 'Holi', 'type': 'Hindu Holiday', 'date': 'Mar 18'},
#  {'name': 'French Language Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 20'},
#  {'name': 'International Day of Happiness',
#   'type': 'United Nations observance',
#   'date': 'Mar 20'},
#  {'name': 'March Equinox', 'type': 'Season', 'date': 'Mar 20'},
#  {'name': 'International Day for the Elimination of Racial Discrimination',
#   'type': 'United Nations observance',
#   'date': 'Mar 21'},
#  {'name': 'World Poetry Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 21'},
#  {'name': 'International Day of Nowruz',
#   'type': 'United Nations observance',
#   'date': 'Mar 21'},
#  {'name': 'World Down Syndrome Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 21'},
#  {'name': 'International Day of Forests',
#   'type': 'United Nations observance',
#   'date': 'Mar 21'},
#  {'name': 'World Water Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 22'},
#  {'name': 'World Meteorological Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 23'},
#  {'name': 'World Tuberculosis Day',
#   'type': 'United Nations observance',
#   'date': 'Mar 24'},
#  {'name': 'International Day for the Right to the Truth concerning Gross Human Rights Violations and for the Dignity of Victims',
#   'type': 'United Nations observance',
#   'date': 'Mar 24'},
#  {'name': 'International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade',
#   'type': 'United Nations observance',
#   'date': 'Mar 25'},
#  {'name': 'International Day of Solidarity with Detained and Missing Staff Members',
#   'type': 'United Nations observance',
#   'date': 'Mar 25'},
#  {'name': 'Maryland Day', 'type': 'Local observance', 'date': 'Mar 25'},
#  {'name': 'Prince Jonah Kuhio Kalanianaole Day observed',
#   'type': 'State Holiday',
#   'date': 'Mar 25'},
#  {'name': 'Earth Hour', 'type': 'Worldwide observance', 'date': 'Mar 26'},
#  {'name': 'Prince Jonah Kuhio Kalanianaole Day',
#   'type': 'State Holiday',
#   'date': 'Mar 26'},
#  {'name': "Seward's Day", 'type': 'State Holiday', 'date': 'Mar 28'},
#  {'name': 'National Vietnam War Veterans Day',
#   'type': 'Observance',
#   'date': 'Mar 29'},
#  {'name': 'Wyoming Veterans Welcome Home Day',
#   'type': 'State Observance',
#   'date': 'Mar 30'},
#  {'name': "Doctors' Day", 'type': 'Observance', 'date': 'Mar 30'},
#  {'name': 'Vietnam Veterans Day',
#   'type': 'State Observance',
#   'date': 'Mar 30'},
#  {'name': 'César Chávez Day', 'type': 'State Holiday', 'date': 'Mar 31'},
#  {'name': "April Fool's Day", 'type': 'Worldwide observance', 'date': 'Apr 1'},
#  {'name': 'Pascua Florida Day observed',
#   'type': 'Local observance',
#   'date': 'Apr 1'},
#  {'name': 'World Autism Awareness Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 2'},
#  {'name': 'Pascua Florida Day', 'type': 'Local observance', 'date': 'Apr 2'},
#  {'name': 'Ramadan Starts', 'type': 'Muslim', 'date': 'Apr 3'},
#  {'name': "United Nations' Mine Awareness Day",
#   'type': 'United Nations observance',
#   'date': 'Apr 4'},
#  {'name': 'International Day of Conscience',
#   'type': 'United Nations observance',
#   'date': 'Apr 5'},
#  {'name': 'International Day of Sport for Development and Peace',
#   'type': 'United Nations observance',
#   'date': 'Apr 6'},
#  {'name': 'National Tartan Day', 'type': 'Observance', 'date': 'Apr 6'},
#  {'name': "United Nations' World Health Day",
#   'type': 'United Nations observance',
#   'date': 'Apr 7'},
#  {'name': 'Day of Remembrance of the Victims of the Rwanda Genocide',
#   'type': 'United Nations observance',
#   'date': 'Apr 7'},
#  {'name': 'Palm Sunday', 'type': 'Christian', 'date': 'Apr 10'},
#  {'name': 'International Day of Human Space Flight',
#   'type': 'United Nations observance',
#   'date': 'Apr 12'},
#  {'name': "National Library Workers' Day",
#   'type': 'Observance',
#   'date': 'Apr 12'},
#  {'name': "Thomas Jefferson's Birthday",
#   'type': 'Observance',
#   'date': 'Apr 13'},
#  {'name': 'Maundy Thursday', 'type': 'Christian', 'date': 'Apr 14'},
#  {'name': 'World Chagas Disease Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 14'},
#  {'name': 'Passover Eve', 'type': 'Jewish holiday', 'date': 'Apr 15'},
#  {'name': 'World Art Day', 'type': 'Worldwide observance', 'date': 'Apr 15'},
#  {'name': 'Good Friday', 'type': 'State Holiday', 'date': 'Apr 15'},
#  {'name': 'Father Damien Day', 'type': 'Local observance', 'date': 'Apr 15'},
#  {'name': 'Emancipation Day observed',
#   'type': 'State Holiday',
#   'date': 'Apr 15'},
#  {'name': 'Arbor Day', 'type': 'State Observance', 'date': 'Apr 15'},
#  {'name': 'State Holiday', 'type': 'State Holiday', 'date': 'Apr 15'},
#  {'name': 'Holy Saturday', 'type': 'Christian', 'date': 'Apr 16'},
#  {'name': 'Passover (first day)', 'type': 'Jewish holiday', 'date': 'Apr 16'},
#  {'name': 'Emancipation Day', 'type': 'State Holiday', 'date': 'Apr 16'},
#  {'name': 'Easter Sunday', 'type': 'Observance, Christian', 'date': 'Apr 17'},
#  {'name': 'International Day for Monuments and Sites',
#   'type': 'Worldwide observance',
#   'date': 'Apr 18'},
#  {'name': 'Easter Monday', 'type': 'Observance, Christian', 'date': 'Apr 18'},
#  {'name': 'Tax Day', 'type': 'Observance', 'date': 'Apr 18'},
#  {'name': "Patriots' Day", 'type': 'State Holiday', 'date': 'Apr 18'},
#  {'name': 'Boston Marathon', 'type': 'Sporting event', 'date': 'Apr 18'},
#  {'name': 'Chinese Language Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 20'},
#  {'name': 'World Creativity and Innovation Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 21'},
#  {'name': 'San Jacinto Day', 'type': 'State Holiday', 'date': 'Apr 21'},
#  {'name': 'Orthodox Good Friday', 'type': 'Orthodox', 'date': 'Apr 22'},
#  {'name': 'Earth Day', 'type': 'United Nations observance', 'date': 'Apr 22'},
#  {'name': 'Oklahoma Day', 'type': 'Local observance', 'date': 'Apr 22'},
#  {'name': 'Last Day of Passover', 'type': 'Jewish holiday', 'date': 'Apr 23'},
#  {'name': 'Orthodox Holy Saturday', 'type': 'Orthodox', 'date': 'Apr 23'},
#  {'name': 'World Book and Copyright Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 23'},
#  {'name': 'English Language Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 23'},
#  {'name': 'Orthodox Easter', 'type': 'Orthodox', 'date': 'Apr 24'},
#  {'name': 'International Day of Multilateralism and Diplomacy for Peace',
#   'type': 'United Nations observance',
#   'date': 'Apr 24'},
#  {'name': 'Orthodox Easter Monday', 'type': 'Orthodox', 'date': 'Apr 25'},
#  {'name': "International Delegate's Day",
#   'type': 'United Nations observance',
#   'date': 'Apr 25'},
#  {'name': 'World Malaria Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 25'},
#  {'name': 'Arbor Day', 'type': 'State Observance', 'date': 'Apr 25'},
#  {'name': 'Confederate Memorial Day',
#   'type': 'State Holiday',
#   'date': 'Apr 25'},
#  {'name': 'Confederate Memorial Day',
#   'type': 'State Holiday',
#   'date': 'Apr 25'},
#  {'name': 'State Holiday', 'type': 'State Observance', 'date': 'Apr 25'},
#  {'name': 'World Intellectual Property Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 26'},
#  {'name': 'International Chernobyl Disaster Remembrance Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 26'},
#  {'name': "Confederate Heroes' Day",
#   'type': 'Local observance',
#   'date': 'Apr 26'},
#  {'name': 'Administrative Professionals Day',
#   'type': 'Observance',
#   'date': 'Apr 27'},
#  {'name': 'Yom HaShoah', 'type': 'Jewish commemoration', 'date': 'Apr 28'},
#  {'name': 'Lailat al-Qadr', 'type': 'Muslim', 'date': 'Apr 28'},
#  {'name': 'International Girls in ICT Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 28'},
#  {'name': 'World Day for Safety and Health at Work',
#   'type': 'United Nations observance',
#   'date': 'Apr 28'},
#  {'name': 'Take our Daughters and Sons to Work Day',
#   'type': 'Observance',
#   'date': 'Apr 28'},
#  {'name': 'Arbor Day', 'type': 'State Holiday', 'date': 'Apr 29'},
#  {'name': 'Arbor Day', 'type': 'State Observance', 'date': 'Apr 29'},
#  {'name': 'International Jazz Day',
#   'type': 'United Nations observance',
#   'date': 'Apr 30'},
#  {'name': 'International Family Equality Day',
#   'type': 'Worldwide observance',
#   'date': 'May 1'},
#  {'name': 'Law Day', 'type': 'Observance', 'date': 'May 1'},
#  {'name': 'Loyalty Day', 'type': 'Observance', 'date': 'May 1'},
#  {'name': 'Lei Day', 'type': 'Local observance', 'date': 'May 1'},
#  {'name': 'First Day of Military Appreciation Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'May 1'},
#  {'name': 'First Day of Asian Pacific American Heritage Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'May 1'},
#  {'name': 'First Day of Jewish American Heritage Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'May 1'},
#  {'name': 'Eid al-Fitr', 'type': 'Muslim', 'date': 'May 2'},
#  {'name': 'World Tuna Day',
#   'type': 'United Nations observance',
#   'date': 'May 2'},
#  {'name': 'World Press Freedom Day',
#   'type': 'United Nations observance',
#   'date': 'May 3'},
#  {'name': 'National Teacher Appreciation Day',
#   'type': 'Observance',
#   'date': 'May 3'},
#  {'name': 'Kent State Shootings Remembrance',
#   'type': 'Local observance',
#   'date': 'May 4'},
#  {'name': 'Rhode Island Independence Day',
#   'type': 'Local observance',
#   'date': 'May 4'},
#  {'name': "Yom Ha'atzmaut", 'type': 'Jewish holiday', 'date': 'May 5'},
#  {'name': 'World Portuguese Language Day',
#   'type': 'United Nations observance',
#   'date': 'May 5'},
#  {'name': 'Cinco de Mayo', 'type': 'Observance', 'date': 'May 5'},
#  {'name': 'National Day of Prayer', 'type': 'Observance', 'date': 'May 5'},
#  {'name': 'West Virginia Day of Prayer',
#   'type': 'State Observance',
#   'date': 'May 5'},
#  {'name': 'Kentucky Oaks', 'type': 'Sporting event', 'date': 'May 6'},
#  {'name': 'National Nurses Day', 'type': 'Observance', 'date': 'May 6'},
#  {'name': 'Military Spouse Appreciation Day',
#   'type': 'Observance',
#   'date': 'May 6'},
#  {'name': 'Military Spouse Appreciation Day',
#   'type': 'State Observance',
#   'date': 'May 6'},
#  {'name': 'Kentucky Derby', 'type': 'Sporting event', 'date': 'May 7'},
#  {'name': 'National Explosive Ordnance Disposal (EOD) Day',
#   'type': 'Observance',
#   'date': 'May 7'},
#  {'name': 'Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War',
#   'type': 'United Nations observance',
#   'date': 'May 8'},
#  {'name': 'World Ovarian Cancer Day',
#   'type': 'Worldwide observance',
#   'date': 'May 8'},
#  {'name': 'World Red Cross and Red Crescent Day',
#   'type': 'Worldwide observance',
#   'date': 'May 8'},
#  {'name': "Mother's Day", 'type': 'Observance', 'date': 'May 8'},
#  {'name': "Mother's Day", 'type': 'State Holiday', 'date': 'May 8'},
#  {'name': 'Truman Day', 'type': 'State Holiday', 'date': 'May 8'},
#  {'name': 'Victory in Europe Day', 'type': 'Observance', 'date': 'May 8'},
#  {'name': 'Truman Day observed', 'type': 'State Holiday', 'date': 'May 9'},
#  {'name': 'International Day of Argania',
#   'type': 'United Nations observance',
#   'date': 'May 10'},
#  {'name': 'Confederate Memorial Day',
#   'type': 'State Holiday',
#   'date': 'May 10'},
#  {'name': 'Confederate Memorial Day',
#   'type': 'Local observance',
#   'date': 'May 10'},
#  {'name': 'Primary Election Day', 'type': 'State Holiday', 'date': 'May 10'},
#  {'name': 'International Nurses Day',
#   'type': 'Worldwide observance',
#   'date': 'May 12'},
#  {'name': 'Friday the 13th', 'type': 'Worldwide observance', 'date': 'May 13'},
#  {'name': 'Native American Day', 'type': 'State Observance', 'date': 'May 13'},
#  {'name': 'World Migratory Bird Day',
#   'type': 'United Nations observance',
#   'date': 'May 14'},
#  {'name': 'International Day of Families',
#   'type': 'United Nations observance',
#   'date': 'May 15'},
#  {'name': 'Peace Officers Memorial Day',
#   'type': 'Observance',
#   'date': 'May 15'},
#  {'name': 'Day of Vesak',
#   'type': 'United Nations observance',
#   'date': 'May 16'},
#  {'name': 'International Day of Living Together in Peace',
#   'type': 'United Nations observance',
#   'date': 'May 16'},
#  {'name': 'International Day of Light',
#   'type': 'United Nations observance',
#   'date': 'May 16'},
#  {'name': 'World Telecommunication and Information Society Day',
#   'type': 'United Nations observance',
#   'date': 'May 17'},
#  {'name': 'Lag BaOmer', 'type': 'Jewish holiday', 'date': 'May 19'},
#  {'name': 'World Bee Day',
#   'type': 'United Nations observance',
#   'date': 'May 20'},
#  {'name': 'World Autoimmune / Autoinflammatory Arthritis Day',
#   'type': 'Worldwide observance',
#   'date': 'May 20'},
#  {'name': 'National Defense Transportation Day',
#   'type': 'Observance',
#   'date': 'May 20'},
#  {'name': 'World Day for Cultural Diversity for Dialogue and Development',
#   'type': 'United Nations observance',
#   'date': 'May 21'},
#  {'name': 'International Tea Day',
#   'type': 'United Nations observance',
#   'date': 'May 21'},
#  {'name': 'Public Lands Day', 'type': 'State Observance', 'date': 'May 21'},
#  {'name': 'Armed Forces Day', 'type': 'Observance', 'date': 'May 21'},
#  {'name': 'Preakness Stakes', 'type': 'Sporting event', 'date': 'May 21'},
#  {'name': 'International Day for Biological Diversity',
#   'type': 'United Nations observance',
#   'date': 'May 22'},
#  {'name': 'National Maritime Day', 'type': 'Observance', 'date': 'May 22'},
#  {'name': 'Harvey Milk Day', 'type': 'Local observance', 'date': 'May 22'},
#  {'name': 'International Day to End Obstetric Fistula',
#   'type': 'United Nations observance',
#   'date': 'May 23'},
#  {'name': 'African Liberation Day',
#   'type': 'Worldwide observance',
#   'date': 'May 25'},
#  {'name': 'Emergency Medical Services for Children Day',
#   'type': 'Observance',
#   'date': 'May 25'},
#  {'name': "National Missing Children's Day",
#   'type': 'Observance',
#   'date': 'May 25'},
#  {'name': 'Ascension Day', 'type': 'Christian', 'date': 'May 26'},
#  {'name': 'International Day of United Nations Peacekeepers',
#   'type': 'United Nations observance',
#   'date': 'May 29'},
#  {'name': 'Memorial Day', 'type': 'Federal Holiday', 'date': 'May 30'},
#  {'name': 'Decoration Day', 'type': 'State Holiday', 'date': 'May 30'},
#  {'name': "Jefferson Davis' Birthday",
#   'type': 'Local observance',
#   'date': 'May 30'},
#  {'name': 'World No Tobacco Day',
#   'type': 'United Nations observance',
#   'date': 'May 31'},
#  {'name': 'Global Day of Parents',
#   'type': 'United Nations observance',
#   'date': 'Jun 1'},
#  {'name': 'First Day of Pride Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'Jun 1'},
#  {'name': 'First Day of Caribbean-American Heritage Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'Jun 1'},
#  {'name': 'Statehood Day', 'type': 'Local observance', 'date': 'Jun 1'},
#  {'name': 'World Bicycle Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 3'},
#  {'name': "Jefferson Davis' Birthday",
#   'type': 'Local observance',
#   'date': 'Jun 3'},
#  {'name': 'International Day of Innocent Children Victims of Aggression',
#   'type': 'United Nations observance',
#   'date': 'Jun 4'},
#  {'name': 'Pentecost', 'type': 'Christian', 'date': 'Jun 5'},
#  {'name': 'Shavuot', 'type': 'Jewish holiday', 'date': 'Jun 5'},
#  {'name': 'World Environment Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 5'},
#  {'name': 'International Day for the Fight against Illegal, Unreported and Unregulated Fishing',
#   'type': 'United Nations observance',
#   'date': 'Jun 5'},
#  {'name': 'Native American Day', 'type': 'State Holiday', 'date': 'Jun 5'},
#  {'name': 'Whit Monday', 'type': 'Christian', 'date': 'Jun 6'},
#  {'name': 'Day of the Russian Language',
#   'type': 'United Nations observance',
#   'date': 'Jun 6'},
#  {'name': "Jefferson Davis' Birthday",
#   'type': 'State Holiday',
#   'date': 'Jun 6'},
#  {'name': 'D-Day', 'type': 'Observance', 'date': 'Jun 6'},
#  {'name': 'World Food Safety Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 7'},
#  {'name': 'World Oceans Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 8'},
#  {'name': 'Kamehameha Day observed',
#   'type': 'State Holiday',
#   'date': 'Jun 10'},
#  {'name': 'Kamehameha Day', 'type': 'State Holiday', 'date': 'Jun 11'},
#  {'name': 'Belmont Stakes', 'type': 'Sporting event', 'date': 'Jun 11'},
#  {'name': 'Trinity Sunday', 'type': 'Christian', 'date': 'Jun 12'},
#  {'name': 'World Day Against Child Labour',
#   'type': 'United Nations observance',
#   'date': 'Jun 12'},
#  {'name': 'Loving Day', 'type': 'Observance', 'date': 'Jun 12'},
#  {'name': 'International Albinism Awareness Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 13'},
#  {'name': 'World Blood Donor Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 14'},
#  {'name': 'Army Birthday', 'type': 'Observance', 'date': 'Jun 14'},
#  {'name': 'Flag Day', 'type': 'Observance', 'date': 'Jun 14'},
#  {'name': 'World Elder Abuse Awareness Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 15'},
#  {'name': 'Corpus Christi', 'type': 'Christian', 'date': 'Jun 16'},
#  {'name': 'International Day of Family Remittances',
#   'type': 'United Nations observance',
#   'date': 'Jun 16'},
#  {'name': 'World Day to Combat Desertification and Drought',
#   'type': 'United Nations observance',
#   'date': 'Jun 17'},
#  {'name': 'Bunker Hill Day', 'type': 'Local holiday', 'date': 'Jun 17'},
#  {'name': 'Juneteenth', 'type': 'State Holiday', 'date': 'Jun 17'},
#  {'name': 'Juneteenth Day', 'type': 'State Holiday', 'date': 'Jun 17'},
#  {'name': 'Juneteenth (substitute)',
#   'type': 'State Holiday',
#   'date': 'Jun 17'},
#  {'name': 'Sustainable Gastronomy Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 18'},
#  {'name': 'Juneteenth Day', 'type': 'State Observance', 'date': 'Jun 18'},
#  {'name': 'International Day for the Elimination of Sexual Violence in Conflict',
#   'type': 'United Nations observance',
#   'date': 'Jun 19'},
#  {'name': "Father's Day", 'type': 'State Holiday', 'date': 'Jun 19'},
#  {'name': "Father's Day", 'type': 'Observance', 'date': 'Jun 19'},
#  {'name': 'Juneteenth', 'type': 'Federal Holiday', 'date': 'Jun 19'},
#  {'name': 'Juneteenth National Freedom Day',
#   'type': 'State Observance',
#   'date': 'Jun 19'},
#  {'name': 'Juneteenth', 'type': 'State Holiday', 'date': 'Jun 19'},
#  {'name': 'Juneteenth National Freedom Day',
#   'type': 'State Holiday',
#   'date': 'Jun 19'},
#  {'name': 'Juneteenth Independence Day',
#   'type': 'Observance',
#   'date': 'Jun 19'},
#  {'name': 'Emancipation Day', 'type': 'State Holiday', 'date': 'Jun 19'},
#  {'name': 'World Refugee Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 20'},
#  {'name': 'Juneteenth (substitute)',
#   'type': 'Federal Holiday',
#   'date': 'Jun 20'},
#  {'name': 'Juneteenth (substitute)',
#   'type': 'State Holiday',
#   'date': 'Jun 20'},
#  {'name': 'West Virginia Day', 'type': 'State Holiday', 'date': 'Jun 20'},
#  {'name': 'American Eagle Day', 'type': 'Observance', 'date': 'Jun 20'},
#  {'name': 'International Day of Yoga',
#   'type': 'United Nations observance',
#   'date': 'Jun 21'},
#  {'name': 'International Day of the Celebration of the Solstice',
#   'type': 'United Nations observance',
#   'date': 'Jun 21'},
#  {'name': 'June Solstice', 'type': 'Season', 'date': 'Jun 21'},
#  {'name': 'Public Service Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 23'},
#  {'name': "International Widows' Day",
#   'type': 'United Nations observance',
#   'date': 'Jun 23'},
#  {'name': 'Day of the Seafarer',
#   'type': 'United Nations observance',
#   'date': 'Jun 25'},
#  {'name': 'International Day Against Drug Abuse and Illicit Trafficking',
#   'type': 'United Nations observance',
#   'date': 'Jun 26'},
#  {'name': 'International Day in Support of Victims of Torture',
#   'type': 'United Nations observance',
#   'date': 'Jun 26'},
#  {'name': 'Micro-, Small and Medium-sized Enterprises Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 27'},
#  {'name': 'Carolina Day', 'type': 'State Observance', 'date': 'Jun 28'},
#  {'name': 'International Day of the Tropics',
#   'type': 'United Nations observance',
#   'date': 'Jun 29'},
#  {'name': 'International Asteroid Day',
#   'type': 'United Nations observance',
#   'date': 'Jun 30'},
#  {'name': 'International Day of Parliamentarism',
#   'type': 'United Nations observance',
#   'date': 'Jun 30'},
#  {'name': 'International Day of Cooperatives',
#   'type': 'United Nations observance',
#   'date': 'Jul 2'},
#  {'name': 'Independence Day', 'type': 'State Holiday', 'date': 'Jul 4'},
#  {'name': 'Independence Day', 'type': 'Federal Holiday', 'date': 'Jul 4'},
#  {'name': 'Eid al-Adha', 'type': 'Muslim', 'date': 'Jul 9'},
#  {'name': 'World Population Day',
#   'type': 'United Nations observance',
#   'date': 'Jul 11'},
#  {'name': 'Nathan Bedford Forrest Day',
#   'type': 'Local observance',
#   'date': 'Jul 13'},
#  {'name': 'Bastille Day', 'type': 'Observance', 'date': 'Jul 14'},
#  {'name': 'World Youth Skills Day',
#   'type': 'United Nations observance',
#   'date': 'Jul 15'},
#  {'name': 'Rural Transit Day', 'type': 'Observance', 'date': 'Jul 16'},
#  {'name': 'Nelson Mandela Day',
#   'type': 'United Nations observance',
#   'date': 'Jul 18'},
#  {'name': 'World Chess Day',
#   'type': 'United Nations observance',
#   'date': 'Jul 20'},
#  {'name': 'Pioneer Day', 'type': 'State Holiday', 'date': 'Jul 24'},
#  {'name': "Parents' Day", 'type': 'Observance', 'date': 'Jul 24'},
#  {'name': 'World Drowning Prevention Day',
#   'type': 'United Nations observance',
#   'date': 'Jul 25'},
#  {'name': 'Pioneer Day observed', 'type': 'State Holiday', 'date': 'Jul 25'},
#  {'name': 'Korean War Veteran Recognition Day',
#   'type': 'State Observance',
#   'date': 'Jul 27'},
#  {'name': 'National Korean War Veterans Armistice Day',
#   'type': 'Observance',
#   'date': 'Jul 27'},
#  {'name': 'World Hepatitis Day',
#   'type': 'United Nations observance',
#   'date': 'Jul 28'},
#  {'name': 'Muharram', 'type': 'Muslim', 'date': 'Jul 30'},
#  {'name': 'International Day of Friendship',
#   'type': 'United Nations observance',
#   'date': 'Jul 30'},
#  {'name': 'World Day Against Trafficking in Persons',
#   'type': 'United Nations observance',
#   'date': 'Jul 30'},
#  {'name': 'Colorado Day', 'type': 'State Observance', 'date': 'Aug 1'},
#  {'name': 'Coast Guard Birthday', 'type': 'Observance', 'date': 'Aug 4'},
#  {'name': 'Barack Obama Day', 'type': 'Observance', 'date': 'Aug 4'},
#  {'name': "Tisha B'Av", 'type': 'Jewish holiday', 'date': 'Aug 7'},
#  {'name': 'American Family Day', 'type': 'State Holiday', 'date': 'Aug 7'},
#  {'name': 'Purple Heart Day', 'type': 'Observance', 'date': 'Aug 7'},
#  {'name': 'Purple Heart Day', 'type': 'State Observance', 'date': 'Aug 7'},
#  {'name': 'Ashura (Tentative Date)', 'type': 'Muslim', 'date': 'Aug 8'},
#  {'name': 'Victory Day', 'type': 'State Holiday', 'date': 'Aug 8'},
#  {'name': "International Day of the World's Indigenous People",
#   'type': 'United Nations observance',
#   'date': 'Aug 9'},
#  {'name': 'Raksha Bandhan', 'type': 'Hindu Holiday', 'date': 'Aug 11'},
#  {'name': 'International Youth Day',
#   'type': 'United Nations observance',
#   'date': 'Aug 12'},
#  {'name': 'National Navajo Code Talkers Day',
#   'type': 'State Holiday',
#   'date': 'Aug 14'},
#  {'name': 'Assumption of Mary', 'type': 'Christian', 'date': 'Aug 15'},
#  {'name': 'Bennington Battle Day', 'type': 'State Holiday', 'date': 'Aug 16'},
#  {'name': 'World Humanitarian Day',
#   'type': 'United Nations observance',
#   'date': 'Aug 19'},
#  {'name': 'Hawaii Statehood Day', 'type': 'State Holiday', 'date': 'Aug 19'},
#  {'name': 'National Aviation Day', 'type': 'Observance', 'date': 'Aug 19'},
#  {'name': 'International Day of Remembrance of and Tribute to the Victims of Terrorism',
#   'type': 'United Nations observance',
#   'date': 'Aug 21'},
#  {'name': 'National Senior Citizens Day',
#   'type': 'Observance',
#   'date': 'Aug 21'},
#  {'name': 'International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief',
#   'type': 'United Nations observance',
#   'date': 'Aug 22'},
#  {'name': 'International Day for the Remembrance of the Slave Trade and its Abolition',
#   'type': 'United Nations observance',
#   'date': 'Aug 23'},
#  {'name': 'Susan B. Anthony Day',
#   'type': 'State Observance',
#   'date': 'Aug 26'},
#  {'name': "Women's Equality Day", 'type': 'Observance', 'date': 'Aug 26'},
#  {'name': 'Lyndon Baines Johnson Day',
#   'type': 'State Holiday',
#   'date': 'Aug 27'},
#  {'name': 'International Day against Nuclear Tests',
#   'type': 'United Nations observance',
#   'date': 'Aug 29'},
#  {'name': 'Ganesh Chaturthi', 'type': 'Hindu Holiday', 'date': 'Aug 30'},
#  {'name': 'International Day of the Victims of Enforced Disappearances',
#   'type': 'United Nations observance',
#   'date': 'Aug 30'},
#  {'name': 'International Day for People of African Descent',
#   'type': 'United Nations observance',
#   'date': 'Aug 31'},
#  {'name': 'International Overdose Awareness Day',
#   'type': 'Worldwide observance',
#   'date': 'Aug 31'},
#  {'name': 'World Sexual Health Day',
#   'type': 'Worldwide observance',
#   'date': 'Sep 4'},
#  {'name': 'International Day of Charity',
#   'type': 'United Nations observance',
#   'date': 'Sep 5'},
#  {'name': 'Labor Day', 'type': 'State Holiday', 'date': 'Sep 5'},
#  {'name': 'Labor Day', 'type': 'Federal Holiday', 'date': 'Sep 5'},
#  {'name': 'International Day of Clean Air for Blue Skies',
#   'type': 'United Nations observance',
#   'date': 'Sep 7'},
#  {'name': "Still's Disease Awareness Day",
#   'type': 'Worldwide observance',
#   'date': 'Sep 7'},
#  {'name': 'International Literacy Day',
#   'type': 'United Nations observance',
#   'date': 'Sep 8'},
#  {'name': 'International Day to Protect Education from Attack',
#   'type': 'United Nations observance',
#   'date': 'Sep 9'},
#  {'name': 'California Admission Day',
#   'type': 'State Holiday',
#   'date': 'Sep 9'},
#  {'name': 'World Suicide Prevention Day',
#   'type': 'Worldwide observance',
#   'date': 'Sep 10'},
#  {'name': 'Carl Garner Federal Lands Cleanup Day',
#   'type': 'Observance',
#   'date': 'Sep 10'},
#  {'name': 'Native American Day', 'type': 'State Observance', 'date': 'Sep 10'},
#  {'name': 'First Responders Day',
#   'type': 'State Observance',
#   'date': 'Sep 11'},
#  {'name': 'Patriot Day', 'type': 'State Observance', 'date': 'Sep 11'},
#  {'name': 'Patriot Day', 'type': 'Observance', 'date': 'Sep 11'},
#  {'name': 'National Grandparents Day', 'type': 'Observance', 'date': 'Sep 11'},
#  {'name': 'Constitution Commemoration Day',
#   'type': 'State Holiday',
#   'date': 'Sep 11'},
#  {'name': 'International Day for South-South Cooperation',
#   'type': 'United Nations observance',
#   'date': 'Sep 12'},
#  {'name': "International Programmers' Day",
#   'type': 'Worldwide observance',
#   'date': 'Sep 13'},
#  {'name': 'International Day of Democracy',
#   'type': 'United Nations observance',
#   'date': 'Sep 15'},
#  {'name': 'First Day of National Hispanic Heritage Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'Sep 15'},
#  {'name': 'International Day for the Preservation of the Ozone Layer',
#   'type': 'United Nations observance',
#   'date': 'Sep 16'},
#  {'name': 'Constitution Day and Citizenship Day observed',
#   'type': 'Observance',
#   'date': 'Sep 16'},
#  {'name': 'National POW/MIA Recognition Day',
#   'type': 'Observance',
#   'date': 'Sep 16'},
#  {'name': 'World Patient Safety Day',
#   'type': 'United Nations observance',
#   'date': 'Sep 17'},
#  {'name': 'Constitution Day and Citizenship Day',
#   'type': 'Observance',
#   'date': 'Sep 17'},
#  {'name': 'National CleanUp Day', 'type': 'Observance', 'date': 'Sep 17'},
#  {'name': 'International Equal Pay Day',
#   'type': 'United Nations observance',
#   'date': 'Sep 18'},
#  {'name': 'Air Force Birthday', 'type': 'Observance', 'date': 'Sep 18'},
#  {'name': 'International Day of Peace',
#   'type': 'United Nations observance',
#   'date': 'Sep 21'},
#  {'name': 'Emancipation Day', 'type': 'Local observance', 'date': 'Sep 22'},
#  {'name': 'September Equinox', 'type': 'Season', 'date': 'Sep 22'},
#  {'name': 'International Day of Sign Languages',
#   'type': 'United Nations observance',
#   'date': 'Sep 23'},
#  {'name': 'International Celebrate Bisexuality Day',
#   'type': 'Worldwide observance',
#   'date': 'Sep 23'},
#  {'name': 'Native American Day', 'type': 'State Observance', 'date': 'Sep 23'},
#  {'name': 'Michigan Indian Day', 'type': 'State Observance', 'date': 'Sep 23'},
#  {'name': 'Public Lands Day', 'type': 'State Observance', 'date': 'Sep 24'},
#  {'name': 'National Public Lands Day', 'type': 'Observance', 'date': 'Sep 24'},
#  {'name': "Gold Star Mother's Day", 'type': 'Observance', 'date': 'Sep 25'},
#  {'name': 'Navratri', 'type': 'Hindu Holiday', 'date': 'Sep 26'},
#  {'name': 'Rosh Hashana', 'type': 'Jewish holiday', 'date': 'Sep 26'},
#  {'name': 'International Day for the Total Elimination of Nuclear Weapons',
#   'type': 'United Nations observance',
#   'date': 'Sep 26'},
#  {'name': 'American Indian Day', 'type': 'State Observance', 'date': 'Sep 26'},
#  {'name': 'Rosh Hashana', 'type': 'State Holiday', 'date': 'Sep 26'},
#  {'name': 'World Tourism Day',
#   'type': 'United Nations observance',
#   'date': 'Sep 27'},
#  {'name': 'International Day for Universal Access to Information',
#   'type': 'United Nations observance',
#   'date': 'Sep 28'},
#  {'name': 'World Rabies Day',
#   'type': 'Worldwide observance',
#   'date': 'Sep 28'},
#  {'name': 'World Maritime Day',
#   'type': 'United Nations observance',
#   'date': 'Sep 29'},
#  {'name': 'International Day of Awareness of Food Loss and Waste',
#   'type': 'United Nations observance',
#   'date': 'Sep 29'},
#  {'name': 'World Heart Day', 'type': 'Worldwide observance', 'date': 'Sep 29'},
#  {'name': 'International Translation Day',
#   'type': 'United Nations observance',
#   'date': 'Sep 30'},
#  {'name': 'American Indian Heritage Day',
#   'type': 'State Observance',
#   'date': 'Sep 30'},
#  {'name': 'International Day of Older Persons',
#   'type': 'United Nations observance',
#   'date': 'Oct 1'},
#  {'name': 'World Vegetarian Day',
#   'type': 'Worldwide observance',
#   'date': 'Oct 1'},
#  {'name': 'International Day of Non-Violence',
#   'type': 'United Nations observance',
#   'date': 'Oct 2'},
#  {'name': 'World Habitat Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 3'},
#  {'name': 'Frances Xavier Cabrini Day',
#   'type': 'State Holiday',
#   'date': 'Oct 3'},
#  {'name': 'Child Health Day', 'type': 'Observance', 'date': 'Oct 3'},
#  {'name': 'Feast of St Francis of Assisi',
#   'type': 'Christian',
#   'date': 'Oct 4'},
#  {'name': 'Dussehra', 'type': 'Hindu Holiday', 'date': 'Oct 4'},
#  {'name': 'Yom Kippur', 'type': 'Jewish holiday', 'date': 'Oct 5'},
#  {'name': "World Teachers' Day",
#   'type': 'United Nations observance',
#   'date': 'Oct 5'},
#  {'name': 'Yom Kippur', 'type': 'State Holiday', 'date': 'Oct 5'},
#  {'name': 'World Cerebral Palsy Day',
#   'type': 'Worldwide observance',
#   'date': 'Oct 6'},
#  {'name': 'German American Day', 'type': 'Observance', 'date': 'Oct 6'},
#  {'name': "The Prophet's Birthday", 'type': 'Muslim', 'date': 'Oct 8'},
#  {'name': "Robert E. Lee's Birthday",
#   'type': 'State Observance',
#   'date': 'Oct 8'},
#  {'name': 'World Post Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 9'},
#  {'name': 'Leif Erikson Day', 'type': 'Observance', 'date': 'Oct 9'},
#  {'name': 'Leif Erikson Day', 'type': 'Local observance', 'date': 'Oct 9'},
#  {'name': 'Chicago Marathon', 'type': 'Sporting event', 'date': 'Oct 9'},
#  {'name': 'First Day of Sukkot', 'type': 'Jewish holiday', 'date': 'Oct 10'},
#  {'name': 'World Mental Health Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 10'},
#  {'name': 'Columbus Day', 'type': 'State Legal Holiday', 'date': 'Oct 10'},
#  {'name': 'Columbus Day', 'type': 'Federal Holiday', 'date': 'Oct 10'},
#  {'name': 'Columbus Day', 'type': 'State Holiday', 'date': 'Oct 10'},
#  {'name': 'Fraternal Day', 'type': 'State Holiday', 'date': 'Oct 10'},
#  {'name': 'Yorktown Victory Day', 'type': 'State Holiday', 'date': 'Oct 10'},
#  {'name': 'Discoverers’ Day', 'type': 'State Observance', 'date': 'Oct 10'},
#  {'name': 'Native American Day', 'type': 'State Observance', 'date': 'Oct 10'},
#  {'name': 'Native American Day', 'type': 'State Holiday', 'date': 'Oct 10'},
#  {'name': "Indigenous People's Day",
#   'type': 'State Observance',
#   'date': 'Oct 10'},
#  {'name': "Indigenous People's Day",
#   'type': 'State Holiday',
#   'date': 'Oct 10'},
#  {'name': "Indigenous People's Day (Tentative Date)",
#   'type': 'State Observance',
#   'date': 'Oct 10'},
#  {'name': 'American Indian Heritage Day',
#   'type': 'State Holiday',
#   'date': 'Oct 10'},
#  {'name': 'International Day of the Girl Child',
#   'type': 'United Nations observance',
#   'date': 'Oct 11'},
#  {'name': 'Casimir Pulaski Day', 'type': 'State Observance', 'date': 'Oct 11'},
#  {'name': 'International Day for Natural Disaster Reduction',
#   'type': 'United Nations observance',
#   'date': 'Oct 12'},
#  {'name': 'World Spanish Language Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 12'},
#  {'name': 'World Sight Day', 'type': 'Worldwide observance', 'date': 'Oct 13'},
#  {'name': 'Navy Birthday', 'type': 'Observance', 'date': 'Oct 13'},
#  {'name': 'International Day of Rural Women',
#   'type': 'United Nations observance',
#   'date': 'Oct 15'},
#  {'name': 'White Cane Safety Day', 'type': 'Observance', 'date': 'Oct 15'},
#  {'name': 'Sweetest Day', 'type': 'Observance', 'date': 'Oct 15'},
#  {'name': 'Last Day of Sukkot', 'type': 'Jewish holiday', 'date': 'Oct 16'},
#  {'name': 'World Food Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 16'},
#  {'name': 'Shmini Atzeret', 'type': 'Jewish holiday', 'date': 'Oct 17'},
#  {'name': 'International Day for the Eradication of Poverty',
#   'type': 'United Nations observance',
#   'date': 'Oct 17'},
#  {'name': "Boss's Day", 'type': 'Observance', 'date': 'Oct 17'},
#  {'name': 'Simchat Torah', 'type': 'Jewish holiday', 'date': 'Oct 18'},
#  {'name': 'Alaska Day', 'type': 'State Holiday', 'date': 'Oct 18'},
#  {'name': 'Diwali/Deepavali', 'type': 'Hindu Holiday', 'date': 'Oct 24'},
#  {'name': 'United Nations Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 24'},
#  {'name': 'World Development Information Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 24'},
#  {'name': 'World Day for Audiovisual Heritage',
#   'type': 'United Nations observance',
#   'date': 'Oct 27'},
#  {'name': 'Nevada Day', 'type': 'State Holiday', 'date': 'Oct 28'},
#  {'name': 'World Stroke Day',
#   'type': 'Worldwide observance',
#   'date': 'Oct 29'},
#  {'name': 'World Cities Day',
#   'type': 'United Nations observance',
#   'date': 'Oct 31'},
#  {'name': 'Halloween', 'type': 'Observance', 'date': 'Oct 31'},
#  {'name': "All Saints' Day", 'type': 'Christian', 'date': 'Nov 1'},
#  {'name': 'World Vegan Day', 'type': 'Worldwide observance', 'date': 'Nov 1'},
#  {'name': 'First Day of Native American Heritage Month',
#   'type': 'Annual Monthly Observance',
#   'date': 'Nov 1'},
#  {'name': "All Souls' Day", 'type': 'Christian', 'date': 'Nov 2'},
#  {'name': 'International Day to End Impunity for Crimes against Journalists',
#   'type': 'United Nations observance',
#   'date': 'Nov 2'},
#  {'name': 'World Tsunami Awareness Day',
#   'type': 'United Nations observance',
#   'date': 'Nov 5'},
#  {'name': 'International Day for Preventing the Exploitation of the Environment in War and Armed Conflict',
#   'type': 'United Nations observance',
#   'date': 'Nov 6'},
#  {'name': 'New York City Marathon', 'type': 'Sporting event', 'date': 'Nov 6'},
#  {'name': 'Daylight Saving Time ends',
#   'type': 'Clock change/Daylight Saving Time',
#   'date': 'Nov 6'},
#  {'name': 'Election Day', 'type': 'Observance', 'date': 'Nov 8'},
#  {'name': 'Election Day', 'type': 'State Holiday', 'date': 'Nov 8'},
#  {'name': 'Susan B. Anthony Day', 'type': 'State Observance', 'date': 'Nov 8'},
#  {'name': 'World Science Day for Peace and Development',
#   'type': 'United Nations observance',
#   'date': 'Nov 10'},
#  {'name': 'Marine Corps Birthday', 'type': 'Observance', 'date': 'Nov 10'},
#  {'name': 'Return Day', 'type': 'State Holiday', 'date': 'Nov 10'},
#  {'name': 'Veterans Day', 'type': 'Federal Holiday', 'date': 'Nov 11'},
#  {'name': 'Veterans Day', 'type': 'State Holiday', 'date': 'Nov 11'},
#  {'name': 'World Pneumonia Day',
#   'type': 'Worldwide observance',
#   'date': 'Nov 12'},
#  {'name': 'World Diabetes Day',
#   'type': 'United Nations observance',
#   'date': 'Nov 14'},
#  {'name': 'Barack Obama Day', 'type': 'Local observance', 'date': 'Nov 14'},
#  {'name': 'International Day for Tolerance',
#   'type': 'United Nations observance',
#   'date': 'Nov 16'},
#  {'name': 'World Philosophy Day',
#   'type': 'United Nations observance',
#   'date': 'Nov 17'},
#  {'name': 'World Prematurity Day',
#   'type': 'Worldwide observance',
#   'date': 'Nov 17'},
#  {'name': 'World Toilet Day',
#   'type': 'United Nations observance',
#   'date': 'Nov 19'},
#  {'name': "International Men's Day",
#   'type': 'Worldwide observance',
#   'date': 'Nov 19'},
#  {'name': 'George Rogers Clark Day',
#   'type': 'State Observance',
#   'date': 'Nov 19'},
#  {'name': 'World Day of Remembrance for Road Traffic Victims',
#   'type': 'United Nations observance',
#   'date': 'Nov 20'},
#  {'name': "Universal Children's Day",
#   'type': 'United Nations observance',
#   'date': 'Nov 20'},
#  {'name': 'Africa Industrialization Day',
#   'type': 'United Nations observance',
#   'date': 'Nov 20'},
#  {'name': 'World Television Day',
#   'type': 'United Nations observance',
#   'date': 'Nov 21'},
#  {'name': 'Thanksgiving Holiday', 'type': 'State Holiday', 'date': 'Nov 23'},
#  {'name': 'Thanksgiving Day', 'type': 'State Holiday', 'date': 'Nov 24'},
#  {'name': 'Thanksgiving Day', 'type': 'Federal Holiday', 'date': 'Nov 24'},
#  {'name': 'International Day for the Elimination of Violence against Women',
#   'type': 'United Nations observance',
#   'date': 'Nov 25'},
#  {'name': 'State Holiday', 'type': 'State Holiday', 'date': 'Nov 25'},
#  {'name': "Presidents' Day", 'type': 'State Holiday', 'date': 'Nov 25'},
#  {'name': "Lincoln's Birthday/Lincoln's Day",
#   'type': 'State Holiday',
#   'date': 'Nov 25'},
#  {'name': 'Day After Thanksgiving', 'type': 'State Holiday', 'date': 'Nov 25'},
#  {'name': 'Black Friday', 'type': 'Observance', 'date': 'Nov 25'},
#  {'name': 'American Indian Heritage Day',
#   'type': 'State Holiday',
#   'date': 'Nov 25'},
#  {'name': 'Native American Heritage Day',
#   'type': 'Observance',
#   'date': 'Nov 25'},
#  {'name': 'Native American Heritage Day',
#   'type': 'State Holiday',
#   'date': 'Nov 25'},
#  {'name': 'First Sunday of Advent', 'type': 'Christian', 'date': 'Nov 27'},
#  {'name': 'Cyber Monday', 'type': 'Observance', 'date': 'Nov 28'},
#  {'name': 'International Day of Solidarity with the Palestinian People',
#   'type': 'United Nations observance',
#   'date': 'Nov 29'},
#  {'name': "Nellie Tayloe Ross's Birthday",
#   'type': 'State Observance',
#   'date': 'Nov 29'},
#  {'name': 'Giving Tuesday', 'type': 'Observance', 'date': 'Nov 29'},
#  {'name': 'Day of Remembrance for all Victims of Chemical Warfare',
#   'type': 'United Nations observance',
#   'date': 'Nov 30'},
#  {'name': 'World AIDS Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 1'},
#  {'name': 'Rosa Parks Day', 'type': 'Local observance', 'date': 'Dec 1'},
#  {'name': 'Rosa Parks Day', 'type': 'State Observance', 'date': 'Dec 1'},
#  {'name': 'International Day for the Abolition of Slavery',
#   'type': 'United Nations observance',
#   'date': 'Dec 2'},
#  {'name': 'International Day of Persons with Disabilities',
#   'type': 'United Nations observance',
#   'date': 'Dec 3'},
#  {'name': 'International Day of Banks',
#   'type': 'United Nations observance',
#   'date': 'Dec 4'},
#  {'name': 'International Volunteer Day for Economic and Social Development',
#   'type': 'United Nations observance',
#   'date': 'Dec 5'},
#  {'name': 'World Soil Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 5'},
#  {'name': 'St Nicholas Day', 'type': 'Observance', 'date': 'Dec 6'},
#  {'name': 'International Civil Aviation Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 7'},
#  {'name': 'Pearl Harbor Remembrance Day',
#   'type': 'Observance',
#   'date': 'Dec 7'},
#  {'name': 'Pearl Harbor Remembrance Day',
#   'type': 'State Observance',
#   'date': 'Dec 7'},
#  {'name': 'Delaware Day', 'type': 'State Observance', 'date': 'Dec 7'},
#  {'name': 'Feast of the Immaculate Conception',
#   'type': 'Christian',
#   'date': 'Dec 8'},
#  {'name': 'International Anti-Corruption Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 9'},
#  {'name': 'World Genocide Commemoration Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 9'},
#  {'name': 'Human Rights Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 10'},
#  {'name': 'Wyoming Day', 'type': 'State Observance', 'date': 'Dec 10'},
#  {'name': 'International Mountain Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 11'},
#  {'name': 'International Day of Neutrality',
#   'type': 'United Nations observance',
#   'date': 'Dec 12'},
#  {'name': 'International Universal Health Coverage Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 12'},
#  {'name': 'Feast of Our Lady of Guadalupe',
#   'type': 'Christian',
#   'date': 'Dec 12'},
#  {'name': 'National Guard Birthday', 'type': 'Observance', 'date': 'Dec 13'},
#  {'name': 'Bill of Rights Day', 'type': 'Observance', 'date': 'Dec 15'},
#  {'name': 'Pan American Aviation Day', 'type': 'Observance', 'date': 'Dec 17'},
#  {'name': 'Wright Brothers Day', 'type': 'Observance', 'date': 'Dec 17'},
#  {'name': 'International Migrants Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 18'},
#  {'name': 'Arabic Language Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 18'},
#  {'name': 'Chanukah/Hanukkah (first day)',
#   'type': 'Jewish holiday',
#   'date': 'Dec 19'},
#  {'name': 'International Human Solidarity Day',
#   'type': 'United Nations observance',
#   'date': 'Dec 20'},
#  {'name': 'December Solstice', 'type': 'Season', 'date': 'Dec 21'},
#  {'name': 'Christmas Eve observed', 'type': 'State Holiday', 'date': 'Dec 23'},
#  {'name': 'Christmas Holiday', 'type': 'State Holiday', 'date': 'Dec 23'},
#  {'name': 'Christmas Eve', 'type': 'State Holiday', 'date': 'Dec 24'},
#  {'name': 'Christmas Eve', 'type': 'Observance, Christian', 'date': 'Dec 24'},
#  {'name': 'Christmas Day', 'type': 'State Holiday', 'date': 'Dec 25'},
#  {'name': 'Christmas Day', 'type': 'Federal Holiday', 'date': 'Dec 25'},
#  {'name': 'Christmas Day', 'type': 'State Holiday', 'date': 'Dec 25'},
#  {'name': 'Last Day of Chanukah', 'type': 'Jewish holiday', 'date': 'Dec 26'},
#  {'name': 'Kwanzaa (first day)', 'type': 'Observance', 'date': 'Dec 26'},
#  {'name': 'Christmas Day (substitute)',
#   'type': 'State Holiday',
#   'date': 'Dec 26'},
#  {'name': 'Christmas Day (substitute)',
#   'type': 'Federal Holiday',
#   'date': 'Dec 26'},
#  {'name': 'Day After Christmas Day',
#   'type': 'State Holiday',
#   'date': 'Dec 26'},
#  {'name': 'International Day of Epidemic Preparedness',
#   'type': 'United Nations observance',
#   'date': 'Dec 27'},
#  {'name': "New Year's Eve observed",
#   'type': 'State Holiday',
#   'date': 'Dec 30'},
#  {'name': 'New Year Holiday', 'type': 'State Holiday', 'date': 'Dec 30'},
#  {'name': "New Year's Eve", 'type': 'Observance', 'date': 'Dec 31'},
#  {'name': "New Year's Eve", 'type': 'State Holiday', 'date': 'Dec 31'}]

# %%
holidaytest = Holiday('fake', 'Dec 15')
type(holidaytest)
# Out:
# __main__.Holiday

# %%
          
# -------------------------------------------
# The HolidayList class acts as a wrapper and container
# For the list of holidays
# Each method has pseudo-code instructions
# --------------------------------------------
class HolidayList:
    def __init__(self):
        self.innerHolidays = []
    
    def addHoliday(self, holidayObj): 
        if isinstance(holidayObj, Holiday) == True:
            print("good")
        else:
            print("bad input")
        
        # Make sure holidayObj is an Holiday Object by checking the type
        # Use innerHolidays.append(holidayObj) to add holiday
        # print to the user that you added a holiday
 
    def findHoliday(HolidayName, Date): 
        pass
        # Find Holiday in innerHolidays
        # Return Holiday

    def removeHoliday(HolidayName, Date):
        # Find Holiday in innerHolidays by searching the name and date combination.
        # remove the Holiday from innerHolidays
        # inform user you deleted the holiday
        pass

    def read_json(filelocation):
        # Read in things from json file location
        # Use addHoliday function to add holidays to inner list.
        pass

    def save_to_json(filelocation):
        # Write out json file to selected file.
        pass
         
    def scrapeHolidays():
        # Scrape Holidays from https://www.timeanddate.com/holidays/us/ 
        # Remember, 2 previous years, current year, and 2  years into the future. You can scrape multiple years by adding year to the timeanddate URL. For example https://www.timeanddate.com/holidays/us/2022
        # Check to see if name and date of holiday is in innerHolidays array
        # Add non-duplicates to innerHolidays
        # Handle any exceptions.     
        pass

    def numHolidays():
        # Return the total number of holidays in innerHolidays
        pass
    
    def filter_holidays_by_week(year, week_number):
        # Use a Lambda function to filter by week number and save this as holidays, use the filter on innerHolidays
        # Week number is part of the the Datetime object
        # Cast filter results as list
        # return your holidays
        pass

    def displayHolidaysInWeek(holidayList):
        # Use your filter_holidays_by_week to get list of holidays within a week as a parameter
        # Output formated holidays in the week. 
        # * Remember to use the holiday __str__ method.
        pass

    def getWeather(weekNum):
        # Convert weekNum to range between two days
        # Use Try / Except to catch problems
        # Query API for weather in that week range
        # Format weather information and return weather string.
        pass

    def viewCurrentWeek():
        # Use the Datetime Module to look up current week and year
        # Use your filter_holidays_by_week function to get the list of holidays 
        # for the current week/year
        # Use your displayHolidaysInWeek function to display the holidays in the week
        # Ask user if they want to get the weather
        # If yes, use your getWeather function and display results
        pass

# %%
fakeList = HolidayList()
fakeList.addHoliday(holidaytest)
# Out:
# good

# %%
def main():
    
    loggedIn = True
    while loggedIn is True: 
        
        print("Welcome to Holiday Management System")
        print("======================")
        print("There are currently 'INSERT VARIABLE' holidays stored in the system.")

        print("Holiday Menu")
        print("======================")
        print(" 1. Add a Holiday \n 2. Remove a Holiday\n 3. Save Holiday List\n 4. View Holidays\n 5. Exit")

        correctInput = False
        while not correctInput:
            userInput = input("Please enter a number between 1 and 5... ")
            try: 
                menuNav = int(userInput)
                if menuNav > 0 and menuNav < 6: 
                    print("good input")
                    correctInput = True
                else:
                    print("Error: Number you entered not in range.")
                    correctInput = False
            except: 
                print("Error: You did not enter a number.")
                correctInput = False

        if menuNav == 1: 
            pass
            ## Ask user what holiday they want to add
            ## Ask what date they want to add it to
            ## print error or success message 

        elif menuNav == 2:
            pass

        elif menuNav == 3:
            pass

        elif menuNav == 4:
            pass

        else:
            pass

        # Large Pseudo Code steps
        # -------------------------------------
        # 1. Initialize HolidayList Object
        # 2. Load JSON file via HolidayList read_json function
        # 3. Scrape additional holidays using your HolidayList scrapeHolidays function.
        # 3. Create while loop for user to keep adding or working with the Calender
        # 4. Display User Menu (Print the menu)
        # 5. Take user input for their action based on Menu and check the user input for errors
        # 6. Run appropriate method from the HolidayList object depending on what the user input is
        # 7. Ask the User if they would like to Continue, if not, end the while loop, ending the program.  If they do wish to continue, keep the program going. 


    if __name__ == "__main__":
        main();


# Additional Hints:
# ---------------------------------------------
# You may need additional helper functions both in and out of the classes, add functions as you need to.
#
# No one function should be more then 50 lines of code, if you need more then 50 lines of code
# excluding comments, break the function into multiple functions.
#
# You can store your raw menu text, and other blocks of texts as raw text files 
# and use placeholder values with the format option.
# Example:
# In the file test.txt is "My name is {fname}, I'm {age}"
# Then you later can read the file into a string "filetxt"
# and substitute the placeholders 
# for example: filetxt.format(fname = "John", age = 36)
# This will make your code far more readable, by seperating text from code.
# Out:
# Welcome to Holiday Management System
# ======================
# There are currently 'INSERT VARIABLE' holidays stores in the system.
# Holiday Menu
# ======================
#  1. Add a Holiday
#  2. Remove a Holiday
#  3. Save Holiday List
#  4. View Holidays
#  5. Exit
# Please enter a number between 1 and 5... 5
# good input

# %%
import json 

fn = 'holidays.json'
with open(fn, 'r') as f:
    holi_tmp = json.load(f)
    
holidayList1 = holi_tmp['holidays']
holidayList1
# Out:
# [{'name': 'Margaret Thatcher Day', 'date': '2021-01-10'},
#  {'name': 'World Sketchnote Day', 'date': '2021-01-11'},
#  {'name': 'Zanzibar Revolution Day', 'date': '2021-01-12'},
#  {'name': 'National Rubber Ducky Day', 'date': '2021-01-13'},
#  {'name': 'Tamil Thai Pongdal Day', 'date': '2021-01-14'},
#  {'name': 'National Bagel Day', 'date': '2021-01-15'},
#  {'name': 'Signing of the Peace Accords', 'date': '2021-01-16'}]
